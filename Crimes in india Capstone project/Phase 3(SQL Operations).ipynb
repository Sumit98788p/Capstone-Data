# %% [markdown]
# SQL Operations

# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# 3.1	Insert records from 42_District_wise_crimes_committed_against_women_2001_2012.csv into a table

# %%
womencrimes_df = pd.read_csv('https://raw.githubusercontent.com/Sumit98788p/Capstone-Data/main/Inserted%20data%20of%20table%20Womencrimes.csv')
womencrimes_df
# Out:
#                state       District  year  rape  Kidnapping  Dowry  \
# 0     ANDHRA PRADESH       ADILABAD  2001    50          30     16
# 1     ANDHRA PRADESH      ANANTAPUR  2001    23          30      7
# 2     ANDHRA PRADESH       CHITTOOR  2001    27          34     14
# 3     ANDHRA PRADESH       CUDDAPAH  2001    20          20     17
# 4     ANDHRA PRADESH  EAST GODAVARI  2001    23          26     12
# ...              ...            ...   ...   ...         ...    ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012     0           0      0
# 9013     LAKSHADWEEP          TOTAL  2012     0           0      0
# 9014      PUDUCHERRY       KARAIKAL  2012     6           2      0
# 9015      PUDUCHERRY     PUDUCHERRY  2012     7          14      0
# 9016      PUDUCHERRY          TOTAL  2012    13          16      0
#
#       Assult_on_women  insult_to_modesty  cruelty_by_husband  importation
# 0                 149                 34                 175            0
# ...

# %% [markdown]
# 3.2	Write SQL query to find the highest number of rapes & Kidnappings that happened in which state, District, and year

# %%
Select w.state,w.District,w.year,w.rape from womencrimes w join
(select max(rape) as Max_rapes from womencrimes) r 
on w.rape = r.max_rapes

# %%
Select w.state,w.District,w.year,w.Kidnapping from womencrimes w join
(select max(Kidnapping) as Max_Kidnappings from womencrimes) r 
on w.Kidnapping = r.Max_Kidnappings

# %%
	state	      District	year	rape
	MADHYA PRADESH	TOTAL	2012	3425

# %%
	state	        District	year	Kidnapping
	UTTAR PRADESH	TOTAL	    2012	7910

# %% [markdown]
# 3.3	Write SQL query to find All the lowest number of rapes & Kidnappings that happened in which state, District, and year

# %%
Select w.state,w.District,w.year,w.rape from womencrimes w join
(select min(rape) as Min_rapes from womencrimes) r 
on w.rape = r.min_rapes

# %%
Select w.state,w.District,w.year,w.Kidnapping from womencrimes w join
(select min(Kidnapping) as Min_Kidnappings from womencrimes) r 
on w.Kidnapping = r.Min_Kidnappings

# %%
lowest_rape_df = pd.read_csv('https://raw.githubusercontent.com/Sumit98788p/Capstone-Data/main/Lowest_rapes%20in%20the%20districts.csv')
lowest_rape_df
# Out:
#                  state           District  year  rape
# 0       ANDHRA PRADESH      GUNTAKAL RLY.  2001     0
# 1       ANDHRA PRADESH  SECUNDERABAD RLY.  2001     0
# 2    ARUNACHAL PRADESH        KAMENG WEST  2001     0
# 3                ASSAM             C.I.D.  2001     0
# 4                BIHAR              ARWAL  2001     0
# ..                 ...                ...   ...   ...
# 493              DELHI                EOW  2012     0
# 494              DELHI        IGI AIRPORT  2012     0
# 495              DELHI                STF  2012     0
# 496        LAKSHADWEEP        LAKSHADWEEP  2012     0
# 497        LAKSHADWEEP              TOTAL  2012     0
#
# [498 rows x 4 columns]

# %%
lowest_kidnapping_df = pd.read_csv('https://raw.githubusercontent.com/Sumit98788p/Capstone-Data/main/Lowest_kidnappings%20in%20the%20districts.csv')
lowest_kidnapping_df
# Out:
#                  state           District  year  Kidnapping
# 0       ANDHRA PRADESH      GUNTAKAL RLY.  2001           0
# 1       ANDHRA PRADESH  SECUNDERABAD RLY.  2001           0
# 2       ANDHRA PRADESH    VIJAYAWADA RLY.  2001           0
# 3    ARUNACHAL PRADESH             TAWANG  2001           0
# 4                ASSAM             C.I.D.  2001           0
# ..                 ...                ...   ...         ...
# 829              DELHI                EOW  2012           0
# 830              DELHI        IGI AIRPORT  2012           0
# 831              DELHI                STF  2012           0
# 832        LAKSHADWEEP        LAKSHADWEEP  2012           0
# 833        LAKSHADWEEP              TOTAL  2012           0
#
# [834 rows x 4 columns]

# %% [markdown]
# 3.4	Insert records from 02_District_wise_crimes_committed_against_ST_2001_2012.csv into a new table

# %%
crimesagainststdf = pd.read_csv('https://raw.githubusercontent.com/Sumit98788p/Capstone-Data/main/Inserted%20data%20of%20table%20crimesagainstst.csv')
crimesagainststdf
# Out:
#                state       district  year  murder  rape  kidnapping  dacoity  \
# 0     ANDHRA PRADESH       ADILABAD  2001       0     1           2        0
# 1     ANDHRA PRADESH      ANANTAPUR  2001       0     0           0        0
# 2     ANDHRA PRADESH       CHITTOOR  2001       0     0           0        0
# 3     ANDHRA PRADESH       CUDDAPAH  2001       0     0           0        0
# 4     ANDHRA PRADESH  EAST GODAVARI  2001       0     0           0        0
# ...              ...            ...   ...     ...   ...         ...      ...
# 9014     LAKSHADWEEP    LAKSHADWEEP  2012       0     0           0        0
# 9015     LAKSHADWEEP          TOTAL  2012       0     0           0        0
# 9016      PUDUCHERRY       KARAIKAL  2012       0     0           0        0
# 9017      PUDUCHERRY     PUDUCHERRY  2012       0     0           0        0
# 9018      PUDUCHERRY          TOTAL  2012       0     0           0        0
#
# ...

# %% [markdown]
# 3.5	Write SQL query to find the highest number of dacoity/robbery in which district.

# %%
Select c.district,c.dacoity,c.year from crimeagainstst c join
(select max(dacoity) as Max_dacoity from crimeagainstst) r 
on c.dacoity = r.Max_dacoity;

# %%
Select c.district,c.robbery,c.year from crimeagainstst c join
(select max(robbery) as Max_robbery from crimeagainstst) r 
on c.robbery = r.Max_robbery

# %%
	district	dacoity  	year
	 DAHOD	     29         2004

# %%
	district	robbery	    year
	DAHOD	      32	    2001

# %% [markdown]
# 3.6	Write SQL query to find in which districts(All) the lowest number of murders happened

# %%
Select c.district,c.murder,c.year from crimeagainstst c join
(select min(murder) as Min_murder from crimeagainstst) r 
on c.murder = r.Min_murder

# %%
lowest_murders_df = pd.read_csv('https://raw.githubusercontent.com/Sumit98788p/Capstone-Data/main/Lowest_murders%20in%20the%20districts.csv')
lowest_murders_df
# Out:
#            district  murder  year
# 0          ADILABAD       0  2001
# 1         ANANTAPUR       0  2001
# 2          CHITTOOR       0  2001
# 3          CUDDAPAH       0  2001
# 4     EAST GODAVARI       0  2001
# ...             ...     ...   ...
# 7964    LAKSHADWEEP       0  2012
# 7965          TOTAL       0  2012
# 7966       KARAIKAL       0  2012
# 7967     PUDUCHERRY       0  2012
# 7968          TOTAL       0  2012
#
# [7969 rows x 3 columns]

# %% [markdown]
# 3.7	Write SQL query to find the number of murders in ascending order in district and yearwise.

# %%
select district,year,murder from crimeagainstst order by murder;

# %%
ascending_murders_df = pd.read_csv('https://raw.githubusercontent.com/Sumit98788p/Capstone-Data/main/Ascending_order_murders.csv')
ascending_murders_df
# Out:
#        district  year  murder
# 0      FAIZABAD  2010       0
# 1     FATEHGARH  2010       0
# 2      FATEHPUR  2010       0
# 3     FIROZABAD  2010       0
# 4        G.R.P.  2010       0
# ...         ...   ...     ...
# 9014    SIMDEGA  2003      22
# 9015     KOHIMA  2003      23
# 9016     KOHIMA  2001      24
# 9017     KOHIMA  2006      28
# 9018      TOTAL  2012      62
#
# [9019 rows x 3 columns]

# %% [markdown]
# 3.8.1	Insert records of STATE/UT, DISTRICT, YEAR, MURDER, ATTEMPT TO MURDER, and RAPE columns only from 01_District_wise_crimes_committed_IPC_2001_2012.csv into a new table

# %%
crimescommitedipc_df = pd.read_csv('https://raw.githubusercontent.com/Sumit98788p/Capstone-Data/main/Inserted%20data%20of%20table%20crimescommitedipc.csv')
crimescommitedipc_df
# Out:
#                state       district  year  murder  attempt_to_murder  rape
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60    50
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125    23
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57    27
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53    20
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67    23
# ...              ...            ...   ...     ...                ...   ...
# 8604        DELHI UT            STF  2012       0                  1     0
# 8605        DELHI UT           WEST  2012      52                 37    79
# 8606     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0     0
# 8607      PUDUCHERRY       KARAIKAL  2012       5                  6     6
# 8608      PUDUCHERRY     PUDUCHERRY  2012      24                 21     7
#
# [8609 rows x 6 columns]

# %% [markdown]
# 3.8.2	Write SQL query to find which District in each state/ut has the highest number of murders yearwise. Your output should show STATE/UT, YEAR, DISTRICT, and MURDERS.

# %%
Select c.state,c.district,c.year,c.murder from crimescommitedipc c join
(select max(murder) as Max_murder,district from crimescommitedipc group by district) r 
on c.murder = r.Max_murder and c.district = r.district

# %% [markdown]
# 3.8.3	Store the above data (the result of 3.8.2) in DataFrame and analyze districts that appear 3 or more than 3 years and print the corresponding state/ut, district, murders, and year in descending order.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Sumit98788p/Internship/main/Exported%20data%20of%203.8.2.csv")
df
# Out:
#                  state      district  year  murder
# 0       ANDHRA PRADESH   RANGA REDDY  2001     214
# 1       ANDHRA PRADESH    VIJAYAWADA  2001      53
# 2       ANDHRA PRADESH      WARANGAL  2001     158
# 3    ARUNACHAL PRADESH     CHANGLANG  2001      11
# 4    ARUNACHAL PRADESH    PAPUM PARE  2001      11
# ..                 ...           ...   ...     ...
# 932           DELHI UT           CAW  2012       0
# 933           DELHI UT       CENTRAL  2012      35
# 934           DELHI UT  CRIME BRANCH  2012       1
# 935           DELHI UT           EOW  2012       0
# 936           DELHI UT      GRP(RLY)  2012      13
#
# [937 rows x 4 columns]

# %%
df['district'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 932     True
# 933    False
# 934     True
# 935     True
# 936    False
# Name: district, Length: 937, dtype: bool

# %%
df.loc[df['district'].duplicated(),:]
# Out:
#                  state         district  year  murder
# 124     ANDHRA PRADESH      RANGA REDDY  2002     214
# 126  ARUNACHAL PRADESH  SUBANSIRI LOWER  2002       8
# 132              BIHAR        JEHANABAD  2002      73
# 143            GUJARAT          NAVSARI  2002      26
# 145            GUJARAT            PATAN  2002      24
# ..                 ...              ...   ...     ...
# 887             PUNJAB             MOGA  2012      37
# 889          RAJASTHAN           BARMER  2012      29
# 932           DELHI UT              CAW  2012       0
# 934           DELHI UT     CRIME BRANCH  2012       1
# 935           DELHI UT              EOW  2012       0
#
# [130 rows x 4 columns]

# %%
district_counts = df.groupby(['state', 'district']).size()

# Filter districts appearing 3 or more years
districts_appearing_multiple_years = district_counts[district_counts >= 3].reset_index()

# Merge with original data to get all details
merged_df = pd.merge(districts_appearing_multiple_years, df, how='left', on=['state', 'district'])

# Print the result in descending order of year
result = merged_df[['state', 'district', 'murder', 'year']].sort_values(by='year', ascending=False)
print("Districts Appearing 3 or More Years with Corresponding State/UT, District, Murders, and Year (Descending Order):")
print(result)
# Out:
# Districts Appearing 3 or More Years with Corresponding State/UT, District, Murders, and Year (Descending Order):
#                 state         district  murder  year
# 35   HIMACHAL PRADESH              CID       0  2012
# 11           DELHI UT              CAW       0  2012
# 31            GUJARAT    SURENDRANAGAR      40  2012
# 49            MANIPUR              CID       0  2012
# 56           NAGALAND         LONGLENG       1  2012
# ..                ...              ...     ...   ...
# 21            GUJARAT          NAVSARI      26  2001
# 3         DAMAN & DIU              DIU       1  2001
# 42        LAKSHADWEEP      LAKSHADWEEP       1  2001
# 26            GUJARAT            PATAN      24  2001
# 0   ARUNACHAL PRADESH  SUBANSIRI LOWER       8  2001
#
# [70 rows x 4 columns]

# %% [markdown]
# 3.8.4	Use appropriate graphs to show your data (the result of 3.8.3)

# %%
plt.figure(figsize=(12,8),facecolor='white')
sns.scatterplot(x='state',y='murder',hue ="year",data=df)
plt.title('Murders in the State dusring 2001 to 2012',fontsize=20,fontweight ='bold')
plt.xticks(fontsize=5,rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,8),facecolor='white')
sns.barplot(x='state',y='murder',data=df)
plt.title('Murders in the State during 2001 to 2012',fontsize=20,fontweight ='bold')
plt.xticks(fontsize=5,rotation=90)
plt.show()

# %%
plt.figure(figsize=(150,70),facecolor='white')
sns.barplot(x='district',y='murder',data=df)
plt.title('Murders in the State dusring 2001 to 2012',fontsize=20,fontweight ='bold')
plt.xticks(fontsize=5,rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,8),facecolor='white')
sns.barplot(x='year',y='murder' ,data=df)
plt.title('Murders in the State dusring 2001 to 2012',fontsize=20,fontweight ='bold')
plt.xticks(fontsize=10,rotation=0)
plt.show()
